# %% [markdown]
# # Generating Cluster Graphs
#
# This example shows how to find the communities in a graph, then contract each community into a single node using :class:`igraph.clustering.VertexClustering`. For this tutorial, we'll use the *Donald Knuth's Les Miserables Network*, which shows the coapperances of characters in the novel *Les Miserables*.

# %%
import pandas as pd
import numpy as np
import tmap as tm
from mhfp.encoder import MHFPEncoder
from mhfp.lsh_forest import LSHForestHelper

df = pd.read_csv('dataset.csv')

perm = 512 
enc = MHFPEncoder(perm) 
fingerprints = [tm.VectorUint(enc.encode(s)) for s in df['canonical_smiles'].unique()]

lsh_forest = tm.LSHForest(d=128, l=8, store=True, file_backed=False, weighted=False)
lsh_forest.batch_add(fingerprints)
lsh_forest.index()

# Get the KNN graph
from_nodes = tm.VectorUint()
to_nodes = tm.VectorUint()
weights = tm.VectorFloat()
lsh_forest.get_knn_graph(from_nodes, to_nodes, weights, k=3, kc=3)

# Convert to numpy arrays if needed
from_array = np.array(from_nodes)
to_array = np.array(to_nodes)
weight_array = np.array(weights)
# Out:
# /home/afloresep/miniforge3/envs/tmap/lib/python3.7/site-packages/mhfp/encoder.py:297: UserWarning: The length of the shingling is 0, which results in an empty set and an all zero folded fingerprint.
#   warnings.warn("The length of the shingling is 0, which results in an empty set and an all zero folded fingerprint.")

# %%
# Convert to numpy arrays if needed
knng_from = np.array(from_nodes)
knng_to = np.array(to_nodes)
knng_weight = np.array(weights)

# %%
# Assuming knng_weight is your numpy array of weights
def transform_weights(weights):
    # Shift and scale weights from [-1, 1] to (0, 1]
    transformed_weights = (weights + 1) / 2
    
    # Ensure no zeros by adding a small epsilon
    epsilon = 1e-6
    transformed_weights = np.clip(transformed_weights, epsilon, 1)
    
    return transformed_weights

# Transform the weights
weights = transform_weights(knng_weight)

# %%
import igraph as ig
import numpy as np
import matplotlib.pyplot as plt

def create_graph_and_detect_communities(from_nodes, to_nodes, weights):
    edges = list(zip(from_nodes, to_nodes))
    unique_nodes = set(from_nodes) | set(to_nodes)
    node_mapping = {node: idx for idx, node in enumerate(unique_nodes)}
    
    g = ig.Graph()
    g.add_vertices(len(unique_nodes))
    g.add_edges([(node_mapping[edge[0]], node_mapping[edge[1]]) for edge in edges])
    g.es['weight'] = weights

    # Perform Leiden community detection (still using weights)
    communities = g.community_leiden(
        objective_function='CPM',
        weights='weight',
        resolution_parameter=0.1,
        beta=0.01,
        n_iterations=50
    )

    return g, communities

def plot_graph(g, filename, communities=None):
    # Compute layout without weights
    layout = g.layout_fruchterman_reingold(
        maxiter=1000,
        area=n_vertices**2, 
        repulsedrad=
    )
    
    fig, ax = plt.subplots(figsize=(12, 8))
    
    # Plot edges (without considering weights)
    edge_xs, edge_ys = [], []
    for edge in g.es:
        x1, y1 = layout[edge.source]
        x2, y2 = layout[edge.target]
        edge_xs.extend([x1, x2, None])
        edge_ys.extend([y1, y2, None])
    ax.plot(edge_xs, edge_ys, color='lightgray', alpha=0.5, zorder=1)
    
    # Plot nodes
    if communities:
        num_communities = len(set(communities.membership))
        color_map = plt.cm.get_cmap('tab20')
        colors = [color_map(i / num_communities) for i in communities.membership]
    else:
        colors = 'skyblue'
    
    ax.scatter([coord[0] for coord in layout], [coord[1] for coord in layout], 
               c=colors, s=20, zorder=2)
    
    ax.axis('off')
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()

# Create graph and detect communities
graph, communities = create_graph_and_detect_communities(knng_from, knng_to, weights)

# Plot original graph
plot_graph(graph, "original_graph.png")

# Plot graph with communities
plot_graph(graph, "graph_with_communities.png", communities)

print("Original graph saved as 'original_graph.png'")
print("Graph with communities saved as 'graph_with_communities.png'")

# Print some basic information
print(f"Number of communities: {len(communities)}")
print(f"Modularity: {communities.modularity}")

# Save the graph with community information
graph.vs['community'] = communities.membership
graph.write_graphml("graph_with_communities.graphml")

print("Graph with communities saved as 'graph_with_communities.graphml'")

# %% [markdown]
# We begin by load the graph from file. The file containing this network can be
# downloaded [here](http://www-personal.umich.edu/~mejn/netdata/).

# %%
import igraph as ig
import numpy as np
import matplotlib.pyplot as plt

def transform_weights(weights):
    # Shift and scale weights from [-1, 1] to (0, 1]
    transformed_weights = (weights + 1) / 2
    
    # Ensure no zeros by adding a small epsilon
    epsilon = 1e-6
    transformed_weights = np.clip(transformed_weights, epsilon, 1)
    
    return transformed_weights

def create_graph_and_detect_communities(from_nodes, to_nodes, weights):
    edges = list(zip(from_nodes, to_nodes))
    unique_nodes = set(from_nodes) | set(to_nodes)
    node_mapping = {node: idx for idx, node in enumerate(unique_nodes)}
    
    g = ig.Graph()
    g.add_vertices(len(unique_nodes))
    g.add_edges([(node_mapping[edge[0]], node_mapping[edge[1]]) for edge in edges])
    g.es['weight'] = weights

    # Perform Leiden community detection
    communities = g.community_leiden(
        objective_function='CPM',
        weights='weight',
        resolution_parameter=2.0,  # Increased to create more communities
        beta=0.01,
        n_iterations=2
    )

    return g, communities, node_mapping

def plot_graph(g, filename, communities=None):
    n_vertices = g.vcount()
    
    # Compute layout with simplified parameters
    layout = g.layout_fruchterman_reingold(
        weights=g.es['weight'],
        niter=500  # Increase iterations for better layout
    )
    
    # Manually spread out the layout
    layout = np.array(layout)
    layout *= np.sqrt(n_vertices)  # Scale the layout based on number of vertices
    
    fig, ax = plt.subplots(figsize=(20, 16))  # Increased figure size
    
    # Plot edges (with reduced alpha for less visual clutter)
    edge_xs, edge_ys = [], []
    for edge in g.es:
        x1, y1 = layout[edge.source]
        x2, y2 = layout[edge.target]
        edge_xs.extend([x1, x2, None])
        edge_ys.extend([y1, y2, None])
    ax.plot(edge_xs, edge_ys, color='lightgray', alpha=0.1, zorder=1)
    
    # Plot nodes
    if communities:
        num_communities = len(set(communities.membership))
        color_map = plt.cm.get_cmap('tab20')
        colors = [color_map(i / num_communities) for i in communities.membership]
    else:
        colors = 'skyblue'
    
    # Adjust node sizes based on degree
    node_sizes = [v.degree() for v in g.vs]
    max_size = 50  # Increased max size
    node_sizes = [5 + (size/max(node_sizes)*max_size) for size in node_sizes]
    
    ax.scatter(layout[:, 0], layout[:, 1], 
               c=colors, s=node_sizes, alpha=0.7, zorder=2)
    
    ax.axis('off')
    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()


# Transform weights
weights = transform_weights(knng_weight)

# Create graph and detect communities
graph, communities, node_mapping = create_graph_and_detect_communities(knng_from, knng_to, weights)

# Plot graph with communities
plot_graph(graph, "graph_with_communities.png", communities)

print("Graph with communities saved as 'graph_with_communities.png'")

# Print some basic information
print(f"Number of communities: {len(communities)}")
print(f"Modularity: {communities.modularity}")

# Save the graph with community information
graph.vs['community'] = communities.membership
graph.write_graphml("graph_with_communities.graphml")

print("Graph with communities saved as 'graph_with_communities.graphml'")

# Optional: Print community sizes
community_sizes = communities.sizes()
print("Community sizes:")
for i, size in enumerate(community_sizes):
    print(f"Community {i}: {size} nodes")
# Out:
# Graph with communities saved as 'graph_with_communities.png'
# Number of communities: 25856
# Modularity: -4.494318514211808e-05
# Graph with communities saved as 'graph_with_communities.graphml'
# Community sizes:
# Community 0: 1 nodes
# Community 1: 1 nodes
# Community 2: 1 nodes
# Community 3: 1 nodes
# Community 4: 1 nodes
# Community 5: 1 nodes
# Community 6: 1 nodes
# Community 7: 1 nodes
# Community 8: 1 nodes
# Community 9: 1 nodes
# Community 10: 1 nodes
# Community 11: 1 nodes
# Community 12: 1 nodes
# Community 13: 1 nodes
# Community 14: 1 nodes
# Community 15: 1 nodes
# Community 16: 1 nodes
# Community 17: 1 nodes
# Community 18: 1 nodes
# Community 19: 1 nodes
# Community 20: 1 nodes
# Community 21: 1 nodes
# Community 22: 1 nodes
# Community 23: 1 nodes
# Community 24: 1 nodes
# Community 25: 1 nodes
# Community 26: 1 nodes
# Community 27: 1 nodes
# Community 28: 1 nodes
# Community 29: 1 nodes
# Community 30: 1 nodes
# Community 31: 1 nodes
# Community 32: 1 nodes
# Community 33: 1 nodes
# Community 34: 1 nodes
# Community 35: 1 nodes
# Community 36: 1 nodes
# Community 37: 1 nodes
# Community 38: 1 nodes
# Community 39: 1 nodes
# Community 40: 1 nodes
# Community 41: 1 nodes
# Community 42: 1 nodes
# Community 43: 1 nodes
# Community 44: 1 nodes
# Community 45: 1 nodes
# Community 46: 1 nodes
# Community 47: 1 nodes
# Community 48: 1 nodes
# Community 49: 1 nodes
# Community 50: 1 nodes
# Community 51: 1 nodes
# Community 52: 1 nodes
# Community 53: 1 nodes
# Community 54: 1 nodes
# Community 55: 1 nodes
# Community 56: 1 nodes
# Community 57: 1 nodes
# Community 58: 1 nodes
# Community 59: 1 nodes
# Community 60: 1 nodes
# Community 61: 1 nodes
# Community 62: 1 nodes
# Community 63: 1 nodes
# Community 64: 1 nodes
# Community 65: 1 nodes
# Community 66: 1 nodes
# Community 67: 1 nodes
# Community 68: 1 nodes
# Community 69: 1 nodes
# Community 70: 1 nodes
# Community 71: 1 nodes
# Community 72: 1 nodes
# Community 73: 1 nodes
# Community 74: 1 nodes
# Community 75: 1 nodes
# Community 76: 1 nodes
# Community 77: 1 nodes
# Community 78: 1 nodes
# Community 79: 1 nodes
# Community 80: 1 nodes
# Community 81: 1 nodes
# Community 82: 1 nodes
# Community 83: 1 nodes
# Community 84: 1 nodes
# Community 85: 1 nodes
# Community 86: 1 nodes
# Community 87: 1 nodes
# Community 88: 1 nodes
# Community 89: 1 nodes
# Community 90: 1 nodes
# Community 91: 1 nodes
# Community 92: 1 nodes
# Community 93: 1 nodes
# Community 94: 1 nodes
# Community 95: 1 nodes
# Community 96: 1 nodes
# Community 97: 1 nodes
# Community 98: 1 nodes
# Community 99: 1 nodes
# Community 100: 1 nodes
# Community 101: 1 nodes
# Community 102: 1 nodes
# Community 103: 1 nodes
# Community 104: 1 nodes
# Community 105: 1 nodes
# Community 106: 1 nodes
# Community 107: 1 nodes
# Community 108: 1 nodes
# Community 109: 1 nodes
# Community 110: 1 nodes
# Community 111: 1 nodes
# Community 112: 1 nodes
# Community 113: 1 nodes
# Community 114: 1 nodes
# Community 115: 1 nodes
# Community 116: 1 nodes
# Community 117: 1 nodes
# Community 118: 1 nodes
# Community 119: 1 nodes
# Community 120: 1 nodes
# Community 121: 1 nodes
# Community 122: 1 nodes
# Community 123: 1 nodes
# Community 124: 1 nodes
# Community 125: 1 nodes
# Community 126: 1 nodes
# Community 127: 1 nodes
# Community 128: 1 nodes
# Community 129: 1 nodes
# Community 130: 1 nodes
# Community 131: 1 nodes
# Community 132: 1 nodes
# Community 133: 1 nodes
# Community 134: 1 nodes
# Community 135: 1 nodes
# Community 136: 1 nodes
# Community 137: 1 nodes
# Community 138: 1 nodes
# Community 139: 1 nodes
# Community 140: 1 nodes
# Community 141: 1 nodes
# Community 142: 1 nodes
# Community 143: 1 nodes
# Community 144: 1 nodes
# Community 145: 1 nodes
# Community 146: 1 nodes
# Community 147: 1 nodes
# Community 148: 1 nodes
# Community 149: 1 nodes
# Community 150: 1 nodes
# Community 151: 1 nodes
# Community 152: 1 nodes
# Community 153: 1 nodes
# Community 154: 1 nodes
# Community 155: 1 nodes
# Community 156: 1 nodes
# Community 157: 1 nodes
# Community 158: 1 nodes
# Community 159: 1 nodes
# Community 160: 1 nodes
# Community 161: 1 nodes
# Community 162: 1 nodes
# Community 163: 1 nodes
# Community 164: 1 nodes
# Community 165: 1 nodes
# Community 166: 1 nodes
# Community 167: 1 nodes
# Community 168: 1 nodes
# Community 169: 1 nodes
# Community 170: 1 nodes
# Community 171: 1 nodes
# Community 172: 1 nodes
# Community 173: 1 nodes
# Community 174: 1 nodes
# Community 175: 1 nodes
# Community 176: 1 nodes
# Community 177: 1 nodes
# Community 178: 1 nodes
# Community 179: 1 nodes
# Community 180: 1 nodes
# Community 181: 1 nodes
# Community 182: 1 nodes
# Community 183: 1 nodes
# Community 184: 1 nodes
# Community 185: 1 nodes
# Community 186: 1 nodes
# Community 187: 1 nodes
# Community 188: 1 nodes
# Community 189: 1 nodes
# Community 190: 1 nodes
# Community 191: 1 nodes
# Community 192: 1 nodes
# Community 193: 1 nodes
# Community 194: 1 nodes
# Community 195: 1 nodes
# Community 196: 1 nodes
# Community 197: 1 nodes
# Community 198: 1 nodes
# Community 199: 1 nodes
# Community 200: 1 nodes
# Community 201: 1 nodes
# Community 202: 1 nodes
# Community 203: 1 nodes
# Community 204: 1 nodes
# Community 205: 1 nodes
# Community 206: 1 nodes
# Community 207: 1 nodes
# Community 208: 1 nodes
# Community 209: 1 nodes
# Community 210: 1 nodes
# Community 211: 1 nodes
# Community 212: 1 nodes
# Community 213: 1 nodes
# Community 214: 1 nodes
# Community 215: 1 nodes
# Community 216: 1 nodes
# Community 217: 1 nodes
# Community 218: 1 nodes
# Community 219: 1 nodes
# Community 220: 1 nodes
# Community 221: 1 nodes
# Community 222: 1 nodes
# Community 223: 1 nodes
# Community 224: 1 nodes
# Community 225: 1 nodes
# Community 226: 1 nodes
# Community 227: 1 nodes
# Community 228: 1 nodes
# Community 229: 1 nodes
# Community 230: 1 nodes
# Community 231: 1 nodes
# Community 232: 1 nodes
# Community 233: 1 nodes
# Community 234: 1 nodes
# Community 235: 1 nodes
# Community 236: 1 nodes
# Community 237: 1 nodes
# Community 238: 1 nodes
# Community 239: 1 nodes
# Community 240: 1 nodes
# Community 241: 1 nodes
# Community 242: 1 nodes
# Community 243: 1 nodes
# Community 244: 1 nodes
# Community 245: 1 nodes
# Community 246: 1 nodes
# Community 247: 1 nodes
# Community 248: 1 nodes
# Community 249: 1 nodes
# Community 250: 1 nodes
# Community 251: 1 nodes
# Community 252: 1 nodes
# Community 253: 1 nodes
# Community 254: 1 nodes
# Community 255: 1 nodes
# Community 256: 1 nodes
# Community 257: 1 nodes
# Community 258: 1 nodes
# Community 259: 1 nodes
# Community 260: 1 nodes
# Community 261: 1 nodes
# Community 262: 1 nodes
# Community 263: 1 nodes
# Community 264: 1 nodes
# Community 265: 1 nodes
# Community 266: 1 nodes
# Community 267: 1 nodes
# Community 268: 1 nodes
# Community 269: 1 nodes
# Community 270: 1 nodes
# Community 271: 1 nodes
# Community 272: 1 nodes
# Community 273: 1 nodes
# Community 274: 1 nodes
# Community 275: 1 nodes
# Community 276: 1 nodes
# Community 277: 1 nodes
# Community 278: 1 nodes
# Community 279: 1 nodes
# Community 280: 1 nodes
# Community 281: 1 nodes
# Community 282: 1 nodes
# Community 283: 1 nodes
# Community 284: 1 nodes
# Community 285: 1 nodes
# Community 286: 1 nodes
# Community 287: 1 nodes
# Community 288: 1 nodes
# Community 289: 1 nodes
# Community 290: 1 nodes
# Community 291: 1 nodes
# Community 292: 1 nodes
# Community 293: 1 nodes
# Community 294: 1 nodes
# Community 295: 1 nodes
# Community 296: 1 nodes
# Community 297: 1 nodes
# Community 298: 1 nodes
# Community 299: 1 nodes
# Community 300: 1 nodes
# Community 301: 1 nodes
# Community 302: 1 nodes
# Community 303: 1 nodes
# Community 304: 1 nodes
# Community 305: 1 nodes
# Community 306: 1 nodes
# Community 307: 1 nodes
# Community 308: 1 nodes
# Community 309: 1 nodes
# Community 310: 1 nodes
# Community 311: 1 nodes
# Community 312: 1 nodes
# Community 313: 1 nodes
# Community 314: 1 nodes
# Community 315: 1 nodes
# Community 316: 1 nodes
# Community 317: 1 nodes
# Community 318: 1 nodes
# Community 319: 1 nodes
# Community 320: 1 nodes
# Community 321: 1 nodes
# Community 322: 1 nodes
# Community 323: 1 nodes
# Community 324: 1 nodes
# Community 325: 1 nodes
# Community 326: 1 nodes
# Community 327: 1 nodes
# Community 328: 1 nodes
# Community 329: 1 nodes
# Community 330: 1 nodes
# Community 331: 1 nodes
# Community 332: 1 nodes
# Community 333: 1 nodes
# Community 334: 1 nodes
# Community 335: 1 nodes
# Community 336: 1 nodes
# Community 337: 1 nodes
# Community 338: 1 nodes
# Community 339: 1 nodes
# Community 340: 1 nodes
# Community 341: 1 nodes
# Community 342: 1 nodes
# Community 343: 1 nodes
# Community 344: 1 nodes
# Community 345: 1 nodes
# Community 346: 1 nodes
# Community 347: 1 nodes
# Community 348: 1 nodes
# Community 349: 1 nodes
# Community 350: 1 nodes
# Community 351: 1 nodes
# Community 352: 1 nodes
# Community 353: 1 nodes
# Community 354: 1 nodes
# Community 355: 1 nodes
# Community 356: 1 nodes
# Community 357: 1 nodes
# Community 358: 1 nodes
# Community 359: 1 nodes
# Community 360: 1 nodes
# Community 361: 1 nodes
# Community 362: 1 nodes
# Community 363: 1 nodes
# Community 364: 1 nodes
# Community 365: 1 nodes
# Community 366: 1 nodes
# Community 367: 1 nodes
# Community 368: 1 nodes
# Community 369: 1 nodes
# Community 370: 1 nodes
# Community 371: 1 nodes
# Community 372: 1 nodes
# Community 373: 1 nodes
# Community 374: 1 nodes
# Community 375: 1 nodes
# Community 376: 1 nodes
# Community 377: 1 nodes
# Community 378: 1 nodes
# Community 379: 1 nodes
# Community 380: 1 nodes
# Community 381: 1 nodes
# Community 382: 1 nodes
# Community 383: 1 nodes
# Community 384: 1 nodes
# Community 385: 1 nodes
# Community 386: 1 nodes
# Community 387: 1 nodes
# Community 388: 1 nodes
# Community 389: 1 nodes
# Community 390: 1 nodes
# Community 391: 1 nodes
# Community 392: 1 nodes
# Community 393: 1 nodes
# Community 394: 1 nodes
# Community 395: 1 nodes
# Community 396: 1 nodes
# Community 397: 1 nodes
# Community 398: 1 nodes
# Community 399: 1 nodes
# Community 400: 1 nodes
# Community 401: 1 nodes
# Community 402: 1 nodes
# Community 403: 1 nodes
# Community 404: 1 nodes
# Community 405: 1 nodes
# Community 406: 1 nodes
# Community 407: 1 nodes
# Community 408: 1 nodes
# Community 409: 1 nodes
# Community 410: 1 nodes
# Community 411: 1 nodes
# Community 412: 1 nodes
# Community 413: 1 nodes
# Community 414: 1 nodes
# Community 415: 1 nodes
# Community 416: 1 nodes
# Community 417: 1 nodes
# Community 418: 1 nodes
# Community 419: 1 nodes
# Community 420: 1 nodes
# Community 421: 1 nodes
# Community 422: 1 nodes
# Community 423: 1 nodes
# Community 424: 1 nodes
# Community 425: 1 nodes
# Community 426: 1 nodes
# Community 427: 1 nodes
# Community 428: 1 nodes
# Community 429: 1 nodes
# Community 430: 1 nodes
# Community 431: 1 nodes
# Community 432: 1 nodes
# Community 433: 1 nodes
# Community 434: 1 nodes
# Community 435: 1 nodes
# Community 436: 1 nodes
# Community 437: 1 nodes
# Community 438: 1 nodes
# Community 439: 1 nodes
# Community 440: 1 nodes
# Community 441: 1 nodes
# Community 442: 1 nodes
# Community 443: 1 nodes
# Community 444: 1 nodes
# Community 445: 1 nodes
# Community 446: 1 nodes
# Community 447: 1 nodes
# Community 448: 1 nodes
# Community 449: 1 nodes
# Community 450: 1 nodes
# Community 451: 1 nodes
# Community 452: 1 nodes
# Community 453: 1 nodes
# Community 454: 1 nodes
# Community 455: 1 nodes
# Community 456: 1 nodes
# Community 457: 1 nodes
# Community 458: 1 nodes
# Community 459: 1 nodes
# Community 460: 1 nodes
# Community 461: 1 nodes
# Community 462: 1 nodes
# Community 463: 1 nodes
# Community 464: 1 nodes
# Community 465: 1 nodes
# Community 466: 1 nodes
# Community 467: 1 nodes
# Community 468: 1 nodes
# Community 469: 1 nodes
# Community 470: 1 nodes
# Community 471: 1 nodes
# Community 472: 1 nodes
# Community 473: 1 nodes
# Community 474: 1 nodes
# Community 475: 1 nodes
# Community 476: 1 nodes
# Community 477: 1 nodes
# Community 478: 1 nodes
# Community 479: 1 nodes
# Community 480: 1 nodes
# Community 481: 1 nodes
# Community 482: 1 nodes
# Community 483: 1 nodes
# Community 484: 1 nodes
# Community 485: 1 nodes
# Community 486: 1 nodes
# Community 487: 1 nodes
# Community 488: 1 nodes
# Community 489: 1 nodes
# Community 490: 1 nodes
# Community 491: 1 nodes
# Community 492: 1 nodes
# Community 493: 1 nodes
# Community 494: 1 nodes
# Community 495: 1 nodes
# Community 496: 1 nodes
# Community 497: 1 nodes
# Community 498: 1 nodes
# Community 499: 1 nodes
# Community 500: 1 nodes
# Community 501: 1 nodes
# Community 502: 1 nodes
# Community 503: 1 nodes
# Community 504: 1 nodes
# Community 505: 1 nodes
# Community 506: 1 nodes
# Community 507: 1 nodes
# Community 508: 1 nodes
# Community 509: 1 nodes
# Community 510: 1 nodes
# Community 511: 1 nodes
# Community 512: 1 nodes
# Community 513: 1 nodes
# Community 514: 1 nodes
# Community 515: 1 nodes
# Community 516: 1 nodes
# Community 517: 1 nodes
# Community 518: 1 nodes
# Community 519: 1 nodes
# Community 520: 1 nodes
# Community 521: 1 nodes
# Community 522: 1 nodes
# Community 523: 1 nodes
# Community 524: 1 nodes
# Community 525: 1 nodes
# Community 526: 1 nodes
# Community 527: 1 nodes
# Community 528: 1 nodes
# Community 529: 1 nodes
# Community 530: 1 nodes
# Community 531: 1 nodes
# Community 532: 1 nodes
# Community 533: 1 nodes
# Community 534: 1 nodes
# Community 535: 1 nodes
# Community 536: 1 nodes
# Community 537: 1 nodes
# Community 538: 1 nodes
# Community 539: 1 nodes
# Community 540: 1 nodes
# Community 541: 1 nodes
# Community 542: 1 nodes
# Community 543: 1 nodes
# Community 544: 1 nodes
# Community 545: 1 nodes
# Community 546: 1 nodes
# Community 547: 1 nodes
# Community 548: 1 nodes
# Community 549: 1 nodes
# Community 550: 1 nodes
# Community 551: 1 nodes
# Community 552: 1 nodes
# Community 553: 1 nodes
# Community 554: 1 nodes
# Community 555: 1 nodes
# Community 556: 1 nodes
# Community 557: 1 nodes
# Community 558: 1 nodes
# Community 559: 1 nodes
# Community 560: 1 nodes
# Community 561: 1 nodes
# Community 562: 1 nodes
# Community 563: 1 nodes
# Community 564: 1 nodes
# Community 565: 1 nodes
# Community 566: 1 nodes
# Community 567: 1 nodes
# Community 568: 1 nodes
# Community 569: 1 nodes
# Community 570: 1 nodes
# Community 571: 1 nodes
# Community 572: 1 nodes
# Community 573: 1 nodes
# Community 574: 1 nodes
# Community 575: 1 nodes
# Community 576: 1 nodes
# Community 577: 1 nodes
# Community 578: 1 nodes
# Community 579: 1 nodes
# Community 580: 1 nodes
# Community 581: 1 nodes
# Community 582: 1 nodes
# Community 583: 1 nodes
# Community 584: 1 nodes
# Community 585: 1 nodes
# Community 586: 1 nodes
# Community 587: 1 nodes
# Community 588: 1 nodes
# Community 589: 1 nodes
# Community 590: 1 nodes
# Community 591: 1 nodes
# Community 592: 1 nodes
# Community 593: 1 nodes
# Community 594: 1 nodes
# Community 595: 1 nodes
# Community 596: 1 nodes
# Community 597: 1 nodes
# Community 598: 1 nodes
# Community 599: 1 nodes
# Community 600: 1 nodes
# Community 601: 1 nodes
# Community 602: 1 nodes
# Community 603: 1 nodes
# Community 604: 1 nodes
# Community 605: 1 nodes
# Community 606: 1 nodes
# Community 607: 1 nodes
# Community 608: 1 nodes
# Community 609: 1 nodes
# Community 610: 1 nodes
# Community 611: 1 nodes
# Community 612: 1 nodes
# Community 613: 1 nodes
# Community 614: 1 nodes
# Community 615: 1 nodes
# Community 616: 1 nodes
# Community 617: 1 nodes
# Community 618: 1 nodes
# Community 619: 1 nodes
# Community 620: 1 nodes
# Community 621: 1 nodes
# Community 622: 1 nodes
# Community 623: 1 nodes
# Community 624: 1 nodes
# Community 625: 1 nodes
# Community 626: 1 nodes
# Community 627: 1 nodes
# Community 628: 1 nodes
# Community 629: 1 nodes
# Community 630: 1 nodes
# Community 631: 1 nodes
# Community 632: 1 nodes
# Community 633: 1 nodes
# Community 634: 1 nodes
# Community 635: 1 nodes
# Community 636: 1 nodes
# Community 637: 1 nodes
# Community 638: 1 nodes
# Community 639: 1 nodes
# Community 640: 1 nodes
# Community 641: 1 nodes
# Community 642: 1 nodes
# Community 643: 1 nodes
# Community 644: 1 nodes
# Community 645: 1 nodes
# Community 646: 1 nodes
# Community 647: 1 nodes
# Community 648: 1 nodes
# Community 649: 1 nodes
# Community 650: 1 nodes
# Community 651: 1 nodes
# Community 652: 1 nodes
# Community 653: 1 nodes
# Community 654: 1 nodes
# Community 655: 1 nodes
# Community 656: 1 nodes
# Community 657: 1 nodes
# Community 658: 1 nodes
# Community 659: 1 nodes
# Community 660: 1 nodes
# Community 661: 1 nodes
# Community 662: 1 nodes
# Community 663: 1 nodes
# Community 664: 1 nodes
# Community 665: 1 nodes
# Community 666: 1 nodes
# Community 667: 1 nodes
# Community 668: 1 nodes
# Community 669: 1 nodes
# Community 670: 1 nodes
# Community 671: 1 nodes
# Community 672: 1 nodes
# Community 673: 1 nodes
# Community 674: 1 nodes
# Community 675: 1 nodes
# Community 676: 1 nodes
# Community 677: 1 nodes
# Community 678: 1 nodes
# Community 679: 1 nodes
# Community 680: 1 nodes
# Community 681: 1 nodes
# Community 682: 1 nodes
# Community 683: 1 nodes
# Community 684: 1 nodes
# Community 685: 1 nodes
# Community 686: 1 nodes
# Community 687: 1 nodes
# Community 688: 1 nodes
# Community 689: 1 nodes
# Community 690: 1 nodes
# Community 691: 1 nodes
# Community 692: 1 nodes
# Community 693: 1 nodes
# Community 694: 1 nodes
# Community 695: 1 nodes
# Community 696: 1 nodes
# Community 697: 1 nodes
# Community 698: 1 nodes
# Community 699: 1 nodes
# Community 700: 1 nodes
# Community 701: 1 nodes
# Community 702: 1 nodes
# Community 703: 1 nodes
# Community 704: 1 nodes
# Community 705: 1 nodes
# Community 706: 1 nodes
# Community 707: 1 nodes
# Community 708: 1 nodes
# Community 709: 1 nodes
# Community 710: 1 nodes
# Community 711: 1 nodes
# Community 712: 1 nodes
# Community 713: 1 nodes
# Community 714: 1 nodes
# Community 715: 1 nodes
# Community 716: 1 nodes
# Community 717: 1 nodes
# Community 718: 1 nodes
# Community 719: 1 nodes
# Community 720: 1 nodes
# Community 721: 1 nodes
# Community 722: 1 nodes
# Community 723: 1 nodes
# Community 724: 1 nodes
# Community 725: 1 nodes
# Community 726: 1 nodes
# Community 727: 1 nodes
# Community 728: 1 nodes
# Community 729: 1 nodes
# Community 730: 1 nodes
# Community 731: 1 nodes
# Community 732: 1 nodes
# Community 733: 1 nodes
# Community 734: 1 nodes
# Community 735: 1 nodes
# Community 736: 1 nodes
# Community 737: 1 nodes
# Community 738: 1 nodes
# Community 739: 1 nodes
# Community 740: 1 nodes
# Community 741: 1 nodes
# Community 742: 1 nodes
# Community 743: 1 nodes
# Community 744: 1 nodes
# Community 745: 1 nodes
# Community 746: 1 nodes
# Community 747: 1 nodes
# Community 748: 1 nodes
# Community 749: 1 nodes
# Community 750: 1 nodes
# Community 751: 1 nodes
# Community 752: 1 nodes
# Community 753: 1 nodes
# Community 754: 1 nodes
# Community 755: 1 nodes
# Community 756: 1 nodes
# Community 757: 1 nodes
# Community 758: 1 nodes
# Community 759: 1 nodes
# Community 760: 1 nodes
# Community 761: 1 nodes
# Community 762: 1 nodes
# Community 763: 1 nodes
# Community 764: 1 nodes
# Community 765: 1 nodes
# Community 766: 1 nodes
# Community 767: 1 nodes
# Community 768: 1 nodes
# Community 769: 1 nodes
# Community 770: 1 nodes
# Community 771: 1 nodes
# Community 772: 1 nodes
# Community 773: 1 nodes
# Community 774: 1 nodes
# Community 775: 1 nodes
# Community 776: 1 nodes
# Community 777: 1 nodes
# Community 778: 1 nodes
# Community 779: 1 nodes
# Community 780: 1 nodes
# Community 781: 1 nodes
# Community 782: 1 nodes
# Community 783: 1 nodes
# Community 784: 1 nodes
# Community 785: 1 nodes
# Community 786: 1 nodes
# Community 787: 1 nodes
# Community 788: 1 nodes
# Community 789: 1 nodes
# Community 790: 1 nodes
# Community 791: 1 nodes
# Community 792: 1 nodes
# Community 793: 1 nodes
# Community 794: 1 nodes
# Community 795: 1 nodes
# Community 796: 1 nodes
# Community 797: 1 nodes
# Community 798: 1 nodes
# Community 799: 1 nodes
# Community 800: 1 nodes
# Community 801: 1 nodes
# Community 802: 1 nodes
# Community 803: 1 nodes
# Community 804: 1 nodes
# Community 805: 1 nodes
# Community 806: 1 nodes
# Community 807: 1 nodes
# Community 808: 1 nodes
# Community 809: 1 nodes
# Community 810: 1 nodes
# Community 811: 1 nodes
# Community 812: 1 nodes
# Community 813: 1 nodes
# Community 814: 1 nodes
# Community 815: 1 nodes
# Community 816: 1 nodes
# Community 817: 1 nodes
# Community 818: 1 nodes
# Community 819: 1 nodes
# Community 820: 1 nodes
# Community 821: 1 nodes
# Community 822: 1 nodes
# Community 823: 1 nodes
# Community 824: 1 nodes
# Community 825: 1 nodes
# Community 826: 1 nodes
# Community 827: 1 nodes
# Community 828: 1 nodes
# Community 829: 1 nodes
# Community 830: 1 nodes
# Community 831: 1 nodes
# Community 832: 1 nodes
# Community 833: 1 nodes
# Community 834: 1 nodes
# Community 835: 1 nodes
# Community 836: 1 nodes
# Community 837: 1 nodes
# Community 838: 1 nodes
# Community 839: 1 nodes
# Community 840: 1 nodes
# Community 841: 1 nodes
# Community 842: 1 nodes
# Community 843: 1 nodes
# Community 844: 1 nodes
# Community 845: 1 nodes
# Community 846: 1 nodes
# Community 847: 1 nodes
# Community 848: 1 nodes
# Community 849: 1 nodes
# Community 850: 1 nodes
# Community 851: 1 nodes
# Community 852: 1 nodes
# Community 853: 1 nodes
# Community 854: 1 nodes
# Community 855: 1 nodes
# Community 856: 1 nodes
# Community 857: 1 nodes
# Community 858: 1 nodes
# Community 859: 1 nodes
# Community 860: 1 nodes
# Community 861: 1 nodes
# Community 862: 1 nodes
# Community 863: 1 nodes
# Community 864: 1 nodes
# Community 865: 1 nodes
# Community 866: 1 nodes
# Community 867: 1 nodes
# Community 868: 1 nodes
# Community 869: 1 nodes
# Community 870: 1 nodes
# Community 871: 1 nodes
# Community 872: 1 nodes
# Community 873: 1 nodes
# Community 874: 1 nodes
# Community 875: 1 nodes
# Community 876: 1 nodes
# Community 877: 1 nodes
# Community 878: 1 nodes
# Community 879: 1 nodes
# Community 880: 1 nodes
# Community 881: 1 nodes
# Community 882: 1 nodes
# Community 883: 1 nodes
# Community 884: 1 nodes
# Community 885: 1 nodes
# Community 886: 1 nodes
# Community 887: 1 nodes
# Community 888: 1 nodes
# Community 889: 1 nodes
# Community 890: 1 nodes
# Community 891: 1 nodes
# Community 892: 1 nodes
# Community 893: 1 nodes
# Community 894: 1 nodes
# Community 895: 1 nodes
# Community 896: 1 nodes
# Community 897: 1 nodes
# Community 898: 1 nodes
# Community 899: 1 nodes
# Community 900: 1 nodes
# Community 901: 1 nodes
# Community 902: 1 nodes
# Community 903: 1 nodes
# Community 904: 1 nodes
# Community 905: 1 nodes
# Community 906: 1 nodes
# Community 907: 1 nodes
# Community 908: 1 nodes
# Community 909: 1 nodes
# Community 910: 1 nodes
# Community 911: 1 nodes
# Community 912: 1 nodes
# Community 913: 1 nodes
# Community 914: 1 nodes
# Community 915: 1 nodes
# Community 916: 1 nodes
# Community 917: 1 nodes
# Community 918: 1 nodes
# Community 919: 1 nodes
# Community 920: 1 nodes
# Community 921: 1 nodes
# Community 922: 1 nodes
# Community 923: 1 nodes
# Community 924: 1 nodes
# Community 925: 1 nodes
# Community 926: 1 nodes
# Community 927: 1 nodes
# Community 928: 1 nodes
# Community 929: 1 nodes
# Community 930: 1 nodes
# Community 931: 1 nodes
# Community 932: 1 nodes
# Community 933: 1 nodes
# Community 934: 1 nodes
# Community 935: 1 nodes
# Community 936: 1 nodes
# Community 937: 1 nodes
# Community 938: 1 nodes
# Community 939: 1 nodes
# Community 940: 1 nodes
# Community 941: 1 nodes
# Community 942: 1 nodes
# Community 943: 1 nodes
# Community 944: 1 nodes
# Community 945: 1 nodes
# Community 946: 1 nodes
# Community 947: 1 nodes
# Community 948: 1 nodes
# Community 949: 1 nodes
# Community 950: 1 nodes
# Community 951: 1 nodes
# Community 952: 1 nodes
# Community 953: 1 nodes
# Community 954: 1 nodes
# Community 955: 1 nodes
# Community 956: 1 nodes
# Community 957: 1 nodes
# Community 958: 1 nodes
# Community 959: 1 nodes
# Community 960: 1 nodes
# Community 961: 1 nodes
# Community 962: 1 nodes
# Community 963: 1 nodes
# Community 964: 1 nodes
# Community 965: 1 nodes
# Community 966: 1 nodes
# Community 967: 1 nodes
# Community 968: 1 nodes
# Community 969: 1 nodes
# Community 970: 1 nodes
# Community 971: 1 nodes
# Community 972: 1 nodes
# Community 973: 1 nodes
# Community 974: 1 nodes
# Community 975: 1 nodes
# Community 976: 1 nodes
# Community 977: 1 nodes
# Community 978: 1 nodes
# Community 979: 1 nodes
# Community 980: 1 nodes
# Community 981: 1 nodes
# Community 982: 1 nodes
# Community 983: 1 nodes
# Community 984: 1 nodes
# Community 985: 1 nodes
# Community 986: 1 nodes
# Community 987: 1 nodes
# Community 988: 1 nodes
# Community 989: 1 nodes
# Community 990: 1 nodes
# Community 991: 1 nodes
# Community 992: 1 nodes
# Community 993: 1 nodes
# Community 994: 1 nodes
# Community 995: 1 nodes
# Community 996: 1 nodes
# Community 997: 1 nodes
# Community 998: 1 nodes
# Community 999: 1 nodes
# Community 1000: 1 nodes
# Community 1001: 1 nodes
# Community 1002: 1 nodes
# Community 1003: 1 nodes
# Community 1004: 1 nodes
# Community 1005: 1 nodes
# Community 1006: 1 nodes
# Community 1007: 1 nodes
# Community 1008: 1 nodes
# Community 1009: 1 nodes
# Community 1010: 1 nodes
# Community 1011: 1 nodes
# Community 1012: 1 nodes
# Community 1013: 1 nodes
# Community 1014: 1 nodes
# Community 1015: 1 nodes
# Community 1016: 1 nodes
# Community 1017: 1 nodes
# Community 1018: 1 nodes
# Community 1019: 1 nodes
# Community 1020: 1 nodes
# Community 1021: 1 nodes
# Community 1022: 1 nodes
# Community 1023: 1 nodes
# Community 1024: 1 nodes
# Community 1025: 1 nodes
# Community 1026: 1 nodes
# Community 1027: 1 nodes
# Community 1028: 1 nodes
# Community 1029: 1 nodes
# Community 1030: 1 nodes
# Community 1031: 1 nodes
# Community 1032: 1 nodes
# Community 1033: 1 nodes
# Community 1034: 1 nodes
# Community 1035: 1 nodes
# Community 1036: 1 nodes
# Community 1037: 1 nodes
# Community 1038: 1 nodes
# Community 1039: 1 nodes
# Community 1040: 1 nodes
# Community 1041: 1 nodes
# Community 1042: 1 nodes
# Community 1043: 1 nodes
# Community 1044: 1 nodes
# Community 1045: 1 nodes
# Community 1046: 1 nodes
# Community 1047: 1 nodes
# Community 1048: 1 nodes
# Community 1049: 1 nodes
# Community 1050: 1 nodes
# Community 1051: 1 nodes
# Community 1052: 1 nodes
# Community 1053: 1 nodes
# Community 1054: 1 nodes
# Community 1055: 1 nodes
# Community 1056: 1 nodes
# Community 1057: 1 nodes
# Community 1058: 1 nodes
# Community 1059: 1 nodes
# Community 1060: 1 nodes
# Community 1061: 1 nodes
# Community 1062: 1 nodes
# Community 1063: 1 nodes
# Community 1064: 1 nodes
# Community 1065: 1 nodes
# Community 1066: 1 nodes
# Community 1067: 1 nodes
# Community 1068: 1 nodes
# Community 1069: 1 nodes
# Community 1070: 1 nodes
# Community 1071: 1 nodes
# Community 1072: 1 nodes
# Community 1073: 1 nodes
# Community 1074: 1 nodes
# Community 1075: 1 nodes
# Community 1076: 1 nodes
# Community 1077: 1 nodes
# Community 1078: 1 nodes
# Community 1079: 1 nodes
# Community 1080: 1 nodes
# Community 1081: 1 nodes
# Community 1082: 1 nodes
# Community 1083: 1 nodes
# Community 1084: 1 nodes
# Community 1085: 1 nodes
# Community 1086: 1 nodes
# Community 1087: 1 nodes
# Community 1088: 1 nodes
# Community 1089: 1 nodes
# Community 1090: 1 nodes
# Community 1091: 1 nodes
# Community 1092: 1 nodes
# Community 1093: 1 nodes
# Community 1094: 1 nodes
# Community 1095: 1 nodes
# Community 1096: 1 nodes
# Community 1097: 1 nodes
# Community 1098: 1 nodes
# Community 1099: 1 nodes
# Community 1100: 1 nodes
# Community 1101: 1 nodes
# Community 1102: 1 nodes
# Community 1103: 1 nodes
# Community 1104: 1 nodes
# Community 1105: 1 nodes
# Community 1106: 1 nodes
# Community 1107: 1 nodes
# Community 1108: 1 nodes
# Community 1109: 1 nodes
# Community 1110: 1 nodes
# Community 1111: 1 nodes
# Community 1112: 1 nodes
# Community 1113: 1 nodes
# Community 1114: 1 nodes
# Community 1115: 1 nodes
# Community 1116: 1 nodes
# Community 1117: 1 nodes
# Community 1118: 1 nodes
# Community 1119: 1 nodes
# Community 1120: 1 nodes
# Community 1121: 1 nodes
# Community 1122: 1 nodes
# Community 1123: 1 nodes
# Community 1124: 1 nodes
# Community 1125: 1 nodes
# Community 1126: 1 nodes
# Community 1127: 1 nodes
# Community 1128: 1 nodes
# Community 1129: 1 nodes
# Community 1130: 1 nodes
# Community 1131: 1 nodes
# Community 1132: 1 nodes
# Community 1133: 1 nodes
# Community 1134: 1 nodes
# Community 1135: 1 nodes
# Community 1136: 1 nodes
# Community 1137: 1 nodes
# Community 1138: 1 nodes
# Community 1139: 1 nodes
# Community 1140: 1 nodes
# Community 1141: 1 nodes
# Community 1142: 1 nodes
# Community 1143: 1 nodes
# Community 1144: 1 nodes
# Community 1145: 1 nodes
# Community 1146: 1 nodes
# Community 1147: 1 nodes
# Community 1148: 1 nodes
# Community 1149: 1 nodes
# Community 1150: 1 nodes
# Community 1151: 1 nodes
# Community 1152: 1 nodes
# Community 1153: 1 nodes
# Community 1154: 1 nodes
# Community 1155: 1 nodes
# Community 1156: 1 nodes
# Community 1157: 1 nodes
# Community 1158: 1 nodes
# Community 1159: 1 nodes
# Community 1160: 1 nodes
# Community 1161: 1 nodes
# Community 1162: 1 nodes
# Community 1163: 1 nodes
# Community 1164: 1 nodes
# Community 1165: 1 nodes
# Community 1166: 1 nodes
# Community 1167: 1 nodes
# Community 1168: 1 nodes
# Community 1169: 1 nodes
# Community 1170: 1 nodes
# Community 1171: 1 nodes
# Community 1172: 1 nodes
# Community 1173: 1 nodes
# Community 1174: 1 nodes
# Community 1175: 1 nodes
# Community 1176: 1 nodes
# Community 1177: 1 nodes
# Community 1178: 1 nodes
# Community 1179: 1 nodes
# Community 1180: 1 nodes
# Community 1181: 1 nodes
# Community 1182: 1 nodes
# Community 1183: 1 nodes
# Community 1184: 1 nodes
# Community 1185: 1 nodes
# Community 1186: 1 nodes
# Community 1187: 1 nodes
# Community 1188: 1 nodes
# Community 1189: 1 nodes
# Community 1190: 1 nodes
# Community 1191: 1 nodes
# Community 1192: 1 nodes
# Community 1193: 1 nodes
# Community 1194: 1 nodes
# Community 1195: 1 nodes
# Community 1196: 1 nodes
# Community 1197: 1 nodes
# Community 1198: 1 nodes
# Community 1199: 1 nodes
# Community 1200: 1 nodes
# Community 1201: 1 nodes
# Community 1202: 1 nodes
# Community 1203: 1 nodes
# Community 1204: 1 nodes
# Community 1205: 1 nodes
# Community 1206: 1 nodes
# Community 1207: 1 nodes
# Community 1208: 1 nodes
# Community 1209: 1 nodes
# Community 1210: 1 nodes
# Community 1211: 1 nodes
# Community 1212: 1 nodes
# Community 1213: 1 nodes
# Community 1214: 1 nodes
# Community 1215: 1 nodes
# Community 1216: 1 nodes
# Community 1217: 1 nodes
# Community 1218: 1 nodes
# Community 1219: 1 nodes
# Community 1220: 1 nodes
# Community 1221: 1 nodes
# Community 1222: 1 nodes
# Community 1223: 1 nodes
# Community 1224: 1 nodes
# Community 1225: 1 nodes
# Community 1226: 1 nodes
# Community 1227: 1 nodes
# Community 1228: 1 nodes
# Community 1229: 1 nodes
# Community 1230: 1 nodes
# Community 1231: 1 nodes
# Community 1232: 1 nodes
# Community 1233: 1 nodes
# Community 1234: 1 nodes
# Community 1235: 1 nodes
# Community 1236: 1 nodes
# Community 1237: 1 nodes
# Community 1238: 1 nodes
# Community 1239: 1 nodes
# Community 1240: 1 nodes
# Community 1241: 1 nodes
# Community 1242: 1 nodes
# Community 1243: 1 nodes
# Community 1244: 1 nodes
# Community 1245: 1 nodes
# Community 1246: 1 nodes
# Community 1247: 1 nodes
# Community 1248: 1 nodes
# Community 1249: 1 nodes
# Community 1250: 1 nodes
# Community 1251: 1 nodes
# Community 1252: 1 nodes
# Community 1253: 1 nodes
# Community 1254: 1 nodes
# Community 1255: 1 nodes
# Community 1256: 1 nodes
# Community 1257: 1 nodes
# Community 1258: 1 nodes
# Community 1259: 1 nodes
# Community 1260: 1 nodes
# Community 1261: 1 nodes
# Community 1262: 1 nodes
# Community 1263: 1 nodes
# Community 1264: 1 nodes
# Community 1265: 1 nodes
# Community 1266: 1 nodes
# Community 1267: 1 nodes
# Community 1268: 1 nodes
# Community 1269: 1 nodes
# Community 1270: 1 nodes
# Community 1271: 1 nodes
# Community 1272: 1 nodes
# Community 1273: 1 nodes
# Community 1274: 1 nodes
# Community 1275: 1 nodes
# Community 1276: 1 nodes
# Community 1277: 1 nodes
# Community 1278: 1 nodes
# Community 1279: 1 nodes
# Community 1280: 1 nodes
# Community 1281: 1 nodes
# Community 1282: 1 nodes
# Community 1283: 1 nodes
# Community 1284: 1 nodes
# Community 1285: 1 nodes
# Community 1286: 1 nodes
# Community 1287: 1 nodes
# Community 1288: 1 nodes
# Community 1289: 1 nodes
# Community 1290: 1 nodes
# Community 1291: 1 nodes
# Community 1292: 1 nodes
# Community 1293: 1 nodes
# Community 1294: 1 nodes
# Community 1295: 1 nodes
# Community 1296: 1 nodes
# Community 1297: 1 nodes
# Community 1298: 1 nodes
# Community 1299: 1 nodes
# Community 1300: 1 nodes
# Community 1301: 1 nodes
# Community 1302: 1 nodes
# Community 1303: 1 nodes
# Community 1304: 1 nodes
# Community 1305: 1 nodes
# Community 1306: 1 nodes
# Community 1307: 1 nodes
# Community 1308: 1 nodes
# Community 1309: 1 nodes
# Community 1310: 1 nodes
# Community 1311: 1 nodes
# Community 1312: 1 nodes
# Community 1313: 1 nodes
# Community 1314: 1 nodes
# Community 1315: 1 nodes
# Community 1316: 1 nodes
# Community 1317: 1 nodes
# Community 1318: 1 nodes
# Community 1319: 1 nodes
# Community 1320: 1 nodes
# Community 1321: 1 nodes
# Community 1322: 1 nodes
# Community 1323: 1 nodes
# Community 1324: 1 nodes
# Community 1325: 1 nodes
# Community 1326: 1 nodes
# Community 1327: 1 nodes
# Community 1328: 1 nodes
# Community 1329: 1 nodes
# Community 1330: 1 nodes
# Community 1331: 1 nodes
# Community 1332: 1 nodes
# Community 1333: 1 nodes
# Community 1334: 1 nodes
# Community 1335: 1 nodes
# Community 1336: 1 nodes
# Community 1337: 1 nodes
# Community 1338: 1 nodes
# Community 1339: 1 nodes
# Community 1340: 1 nodes
# Community 1341: 1 nodes
# Community 1342: 1 nodes
# Community 1343: 1 nodes
# Community 1344: 1 nodes
# Community 1345: 1 nodes
# Community 1346: 1 nodes
# Community 1347: 1 nodes
# Community 1348: 1 nodes
# Community 1349: 1 nodes
# Community 1350: 1 nodes
# Community 1351: 1 nodes
# Community 1352: 1 nodes
# Community 1353: 1 nodes
# Community 1354: 1 nodes
# Community 1355: 1 nodes
# Community 1356: 1 nodes
# Community 1357: 1 nodes
# Community 1358: 1 nodes
# Community 1359: 1 nodes
# Community 1360: 1 nodes
# Community 1361: 1 nodes
# Community 1362: 1 nodes
# Community 1363: 1 nodes
# Community 1364: 1 nodes
# Community 1365: 1 nodes
# Community 1366: 1 nodes
# Community 1367: 1 nodes
# Community 1368: 1 nodes
# Community 1369: 1 nodes
# Community 1370: 1 nodes
# Community 1371: 1 nodes
# Community 1372: 1 nodes
# Community 1373: 1 nodes
# Community 1374: 1 nodes
# Community 1375: 1 nodes
# Community 1376: 1 nodes
# Community 1377: 1 nodes
# Community 1378: 1 nodes
# Community 1379: 1 nodes
# Community 1380: 1 nodes
# Community 1381: 1 nodes
# Community 1382: 1 nodes
# Community 1383: 1 nodes
# Community 1384: 1 nodes
# Community 1385: 1 nodes
# Community 1386: 1 nodes
# Community 1387: 1 nodes
# Community 1388: 1 nodes
# Community 1389: 1 nodes
# Community 1390: 1 nodes
# Community 1391: 1 nodes
# Community 1392: 1 nodes
# Community 1393: 1 nodes
# Community 1394: 1 nodes
# Community 1395: 1 nodes
# Community 1396: 1 nodes
# Community 1397: 1 nodes
# Community 1398: 1 nodes
# Community 1399: 1 nodes
# Community 1400: 1 nodes
# Community 1401: 1 nodes
# Community 1402: 1 nodes
# Community 1403: 1 nodes
# Community 1404: 1 nodes
# Community 1405: 1 nodes
# Community 1406: 1 nodes
# Community 1407: 1 nodes
# Community 1408: 1 nodes
# Community 1409: 1 nodes
# Community 1410: 1 nodes
# Community 1411: 1 nodes
# Community 1412: 1 nodes
# Community 1413: 1 nodes
# Community 1414: 1 nodes
# Community 1415: 1 nodes
# Community 1416: 1 nodes
# Community 1417: 1 nodes
# Community 1418: 1 nodes
# Community 1419: 1 nodes
# Community 1420: 1 nodes
# Community 1421: 1 nodes
# Community 1422: 1 nodes
# Community 1423: 1 nodes
# Community 1424: 1 nodes
# Community 1425: 1 nodes
# Community 1426: 1 nodes
# Community 1427: 1 nodes
# Community 1428: 1 nodes
# Community 1429: 1 nodes
# Community 1430: 1 nodes
# Community 1431: 1 nodes
# Community 1432: 1 nodes
# Community 1433: 1 nodes
# Community 1434: 1 nodes
# Community 1435: 1 nodes
# Community 1436: 1 nodes
# Community 1437: 1 nodes
# Community 1438: 1 nodes
# Community 1439: 1 nodes
# Community 1440: 1 nodes
# Community 1441: 1 nodes
# Community 1442: 1 nodes
# Community 1443: 1 nodes
# Community 1444: 1 nodes
# Community 1445: 1 nodes
# Community 1446: 1 nodes
# Community 1447: 1 nodes
# Community 1448: 1 nodes
# Community 1449: 1 nodes
# Community 1450: 1 nodes
# Community 1451: 1 nodes
# Community 1452: 1 nodes
# Community 1453: 1 nodes
# Community 1454: 1 nodes
# Community 1455: 1 nodes
# Community 1456: 1 nodes
# Community 1457: 1 nodes
# Community 1458: 1 nodes
# Community 1459: 1 nodes
# Community 1460: 1 nodes
# Community 1461: 1 nodes
# Community 1462: 1 nodes
# Community 1463: 1 nodes
# Community 1464: 1 nodes
# Community 1465: 1 nodes
# Community 1466: 1 nodes
# Community 1467: 1 nodes
# Community 1468: 1 nodes
# Community 1469: 1 nodes
# Community 1470: 1 nodes
# Community 1471: 1 nodes
# Community 1472: 1 nodes
# Community 1473: 1 nodes
# Community 1474: 1 nodes
# Community 1475: 1 nodes
# Community 1476: 1 nodes
# Community 1477: 1 nodes
# Community 1478: 1 nodes
# Community 1479: 1 nodes
# Community 1480: 1 nodes
# Community 1481: 1 nodes
# Community 1482: 1 nodes
# Community 1483: 1 nodes
# Community 1484: 1 nodes
# Community 1485: 1 nodes
# Community 1486: 1 nodes
# Community 1487: 1 nodes
# Community 1488: 1 nodes
# Community 1489: 1 nodes
# Community 1490: 1 nodes
# Community 1491: 1 nodes
# Community 1492: 1 nodes
# Community 1493: 1 nodes
# Community 1494: 1 nodes
# Community 1495: 1 nodes
# Community 1496: 1 nodes
# Community 1497: 1 nodes
# Community 1498: 1 nodes
# Community 1499: 1 nodes
# Community 1500: 1 nodes
# Community 1501: 1 nodes
# Community 1502: 1 nodes
# Community 1503: 1 nodes
# Community 1504: 1 nodes
# Community 1505: 1 nodes
# Community 1506: 1 nodes
# Community 1507: 1 nodes
# Community 1508: 1 nodes
# Community 1509: 1 nodes
# Community 1510: 1 nodes
# Community 1511: 1 nodes
# Community 1512: 1 nodes
# Community 1513: 1 nodes
# Community 1514: 1 nodes
# Community 1515: 1 nodes
# Community 1516: 1 nodes
# Community 1517: 1 nodes
# Community 1518: 1 nodes
# Community 1519: 1 nodes
# Community 1520: 1 nodes
# Community 1521: 1 nodes
# Community 1522: 1 nodes
# Community 1523: 1 nodes
# Community 1524: 1 nodes
# Community 1525: 1 nodes
# Community 1526: 1 nodes
# Community 1527: 1 nodes
# Community 1528: 1 nodes
# Community 1529: 1 nodes
# Community 1530: 1 nodes
# Community 1531: 1 nodes
# Community 1532: 1 nodes
# Community 1533: 1 nodes
# Community 1534: 1 nodes
# Community 1535: 1 nodes
# Community 1536: 1 nodes
# Community 1537: 1 nodes
# Community 1538: 1 nodes
# Community 1539: 1 nodes
# Community 1540: 1 nodes
# Community 1541: 1 nodes
# Community 1542: 1 nodes
# Community 1543: 1 nodes
# Community 1544: 1 nodes
# Community 1545: 1 nodes
# Community 1546: 1 nodes
# Community 1547: 1 nodes
# Community 1548: 1 nodes
# Community 1549: 1 nodes
# Community 1550: 1 nodes
# Community 1551: 1 nodes
# Community 1552: 1 nodes
# Community 1553: 1 nodes
# Community 1554: 1 nodes
# Community 1555: 1 nodes
# Community 1556: 1 nodes
# Community 1557: 1 nodes
# Community 1558: 1 nodes
# Community 1559: 1 nodes
# Community 1560: 1 nodes
# Community 1561: 1 nodes
# Community 1562: 1 nodes
# Community 1563: 1 nodes
# Community 1564: 1 nodes
# Community 1565: 1 nodes
# Community 1566: 1 nodes
# Community 1567: 1 nodes
# Community 1568: 1 nodes
# Community 1569: 1 nodes
# Community 1570: 1 nodes
# Community 1571: 1 nodes
# Community 1572: 1 nodes
# Community 1573: 1 nodes
# Community 1574: 1 nodes
# Community 1575: 1 nodes
# Community 1576: 1 nodes
# Community 1577: 1 nodes
# Community 1578: 1 nodes
# Community 1579: 1 nodes
# Community 1580: 1 nodes
# Community 1581: 1 nodes
# Community 1582: 1 nodes
# Community 1583: 1 nodes
# Community 1584: 1 nodes
# Community 1585: 1 nodes
# Community 1586: 1 nodes
# Community 1587: 1 nodes
# Community 1588: 1 nodes
# Community 1589: 1 nodes
# Community 1590: 1 nodes
# Community 1591: 1 nodes
# Community 1592: 1 nodes
# Community 1593: 1 nodes
# Community 1594: 1 nodes
# Community 1595: 1 nodes
# Community 1596: 1 nodes
# Community 1597: 1 nodes
# Community 1598: 1 nodes
# Community 1599: 1 nodes
# Community 1600: 1 nodes
# Community 1601: 1 nodes
# Community 1602: 1 nodes
# Community 1603: 1 nodes
# Community 1604: 1 nodes
# Community 1605: 1 nodes
# Community 1606: 1 nodes
# Community 1607: 1 nodes
# Community 1608: 1 nodes
# Community 1609: 1 nodes
# Community 1610: 1 nodes
# Community 1611: 1 nodes
# Community 1612: 1 nodes
# Community 1613: 1 nodes
# Community 1614: 1 nodes
# Community 1615: 1 nodes
# Community 1616: 1 nodes
# Community 1617: 1 nodes
# Community 1618: 1 nodes
# Community 1619: 1 nodes
# Community 1620: 1 nodes
# Community 1621: 1 nodes
# Community 1622: 1 nodes
# Community 1623: 1 nodes
# Community 1624: 1 nodes
# Community 1625: 1 nodes
# Community 1626: 1 nodes
# Community 1627: 1 nodes
# Community 1628: 1 nodes
# Community 1629: 1 nodes
# Community 1630: 1 nodes
# Community 1631: 1 nodes
# Community 1632: 1 nodes
# Community 1633: 1 nodes
# Community 1634: 1 nodes
# Community 1635: 1 nodes
# Community 1636: 1 nodes
# Community 1637: 1 nodes
# Community 1638: 1 nodes
# Community 1639: 1 nodes
# Community 1640: 1 nodes
# Community 1641: 1 nodes
# Community 1642: 1 nodes
# Community 1643: 1 nodes
# Community 1644: 1 nodes
# Community 1645: 1 nodes
# Community 1646: 1 nodes
# Community 1647: 1 nodes
# Community 1648: 1 nodes
# Community 1649: 1 nodes
# Community 1650: 1 nodes
# Community 1651: 1 nodes
# Community 1652: 1 nodes
# Community 1653: 1 nodes
# Community 1654: 1 nodes
# Community 1655: 1 nodes
# Community 1656: 1 nodes
# Community 1657: 1 nodes
# Community 1658: 1 nodes
# Community 1659: 1 nodes
# Community 1660: 1 nodes
# Community 1661: 1 nodes
# Community 1662: 1 nodes
# Community 1663: 1 nodes
# Community 1664: 1 nodes
# Community 1665: 1 nodes
# Community 1666: 1 nodes
# Community 1667: 1 nodes
# Community 1668: 1 nodes
# Community 1669: 1 nodes
# Community 1670: 1 nodes
# Community 1671: 1 nodes
# Community 1672: 1 nodes
# Community 1673: 1 nodes
# Community 1674: 1 nodes
# Community 1675: 1 nodes
# Community 1676: 1 nodes
# Community 1677: 1 nodes
# Community 1678: 1 nodes
# Community 1679: 1 nodes
# Community 1680: 1 nodes
# Community 1681: 1 nodes
# Community 1682: 1 nodes
# Community 1683: 1 nodes
# Community 1684: 1 nodes
# Community 1685: 1 nodes
# Community 1686: 1 nodes
# Community 1687: 1 nodes
# Community 1688: 1 nodes
# Community 1689: 1 nodes
# Community 1690: 1 nodes
# Community 1691: 1 nodes
# Community 1692: 1 nodes
# Community 1693: 1 nodes
# Community 1694: 1 nodes
# Community 1695: 1 nodes
# Community 1696: 1 nodes
# Community 1697: 1 nodes
# Community 1698: 1 nodes
# Community 1699: 1 nodes
# Community 1700: 1 nodes
# Community 1701: 1 nodes
# Community 1702: 1 nodes
# Community 1703: 1 nodes
# Community 1704: 1 nodes
# Community 1705: 1 nodes
# Community 1706: 1 nodes
# Community 1707: 1 nodes
# Community 1708: 1 nodes
# Community 1709: 1 nodes
# Community 1710: 1 nodes
# Community 1711: 1 nodes
# Community 1712: 1 nodes
# Community 1713: 1 nodes
# Community 1714: 1 nodes
# Community 1715: 1 nodes
# Community 1716: 1 nodes
# Community 1717: 1 nodes
# Community 1718: 1 nodes
# Community 1719: 1 nodes
# Community 1720: 1 nodes
# Community 1721: 1 nodes
# Community 1722: 1 nodes
# Community 1723: 1 nodes
# Community 1724: 1 nodes
# Community 1725: 1 nodes
# Community 1726: 1 nodes
# Community 1727: 1 nodes
# Community 1728: 1 nodes
# Community 1729: 1 nodes
# Community 1730: 1 nodes
# Community 1731: 1 nodes
# Community 1732: 1 nodes
# Community 1733: 1 nodes
# Community 1734: 1 nodes
# Community 1735: 1 nodes
# Community 1736: 1 nodes
# Community 1737: 1 nodes
# Community 1738: 1 nodes
# Community 1739: 1 nodes
# Community 1740: 1 nodes
# Community 1741: 1 nodes
# Community 1742: 1 nodes
# Community 1743: 1 nodes
# Community 1744: 1 nodes
# Community 1745: 1 nodes
# Community 1746: 1 nodes
# Community 1747: 1 nodes
# Community 1748: 1 nodes
# Community 1749: 1 nodes
# Community 1750: 1 nodes
# Community 1751: 1 nodes
# Community 1752: 1 nodes
# Community 1753: 1 nodes
# Community 1754: 1 nodes
# Community 1755: 1 nodes
# Community 1756: 1 nodes
# Community 1757: 1 nodes
# Community 1758: 1 nodes
# Community 1759: 1 nodes
# Community 1760: 1 nodes
# Community 1761: 1 nodes
# Community 1762: 1 nodes
# Community 1763: 1 nodes
# Community 1764: 1 nodes
# Community 1765: 1 nodes
# Community 1766: 1 nodes
# Community 1767: 1 nodes
# Community 1768: 1 nodes
# Community 1769: 1 nodes
# Community 1770: 1 nodes
# Community 1771: 1 nodes
# Community 1772: 1 nodes
# Community 1773: 1 nodes
# Community 1774: 1 nodes
# Community 1775: 1 nodes
# Community 1776: 1 nodes
# Community 1777: 1 nodes
# Community 1778: 1 nodes
# Community 1779: 1 nodes
# Community 1780: 1 nodes
# Community 1781: 1 nodes
# Community 1782: 1 nodes
# Community 1783: 1 nodes
# Community 1784: 1 nodes
# Community 1785: 1 nodes
# Community 1786: 1 nodes
# Community 1787: 1 nodes
# Community 1788: 1 nodes
# Community 1789: 1 nodes
# Community 1790: 1 nodes
# Community 1791: 1 nodes
# Community 1792: 1 nodes
# Community 1793: 1 nodes
# Community 1794: 1 nodes
# Community 1795: 1 nodes
# Community 1796: 1 nodes
# Community 1797: 1 nodes
# Community 1798: 1 nodes
# Community 1799: 1 nodes
# Community 1800: 1 nodes
# Community 1801: 1 nodes
# Community 1802: 1 nodes
# Community 1803: 1 nodes
# Community 1804: 1 nodes
# Community 1805: 1 nodes
# Community 1806: 1 nodes
# Community 1807: 1 nodes
# Community 1808: 1 nodes
# Community 1809: 1 nodes
# Community 1810: 1 nodes
# Community 1811: 1 nodes
# Community 1812: 1 nodes
# Community 1813: 1 nodes
# Community 1814: 1 nodes
# Community 1815: 1 nodes
# Community 1816: 1 nodes
# Community 1817: 1 nodes
# Community 1818: 1 nodes
# Community 1819: 1 nodes
# Community 1820: 1 nodes
# Community 1821: 1 nodes
# Community 1822: 1 nodes
# Community 1823: 1 nodes
# Community 1824: 1 nodes
# Community 1825: 1 nodes
# Community 1826: 1 nodes
# Community 1827: 1 nodes
# Community 1828: 1 nodes
# Community 1829: 1 nodes
# Community 1830: 1 nodes
# Community 1831: 1 nodes
# Community 1832: 1 nodes
# Community 1833: 1 nodes
# Community 1834: 1 nodes
# Community 1835: 1 nodes
# Community 1836: 1 nodes
# Community 1837: 1 nodes
# Community 1838: 1 nodes
# Community 1839: 1 nodes
# Community 1840: 1 nodes
# Community 1841: 1 nodes
# Community 1842: 1 nodes
# Community 1843: 1 nodes
# Community 1844: 1 nodes
# Community 1845: 1 nodes
# Community 1846: 1 nodes
# Community 1847: 1 nodes
# Community 1848: 1 nodes
# Community 1849: 1 nodes
# Community 1850: 1 nodes
# Community 1851: 1 nodes
# Community 1852: 1 nodes
# Community 1853: 1 nodes
# Community 1854: 1 nodes
# Community 1855: 1 nodes
# Community 1856: 1 nodes
# Community 1857: 1 nodes
# Community 1858: 1 nodes
# Community 1859: 1 nodes
# Community 1860: 1 nodes
# Community 1861: 1 nodes
# Community 1862: 1 nodes
# Community 1863: 1 nodes
# Community 1864: 1 nodes
# Community 1865: 1 nodes
# Community 1866: 1 nodes
# Community 1867: 1 nodes
# Community 1868: 1 nodes
# Community 1869: 1 nodes
# Community 1870: 1 nodes
# Community 1871: 1 nodes
# Community 1872: 1 nodes
# Community 1873: 1 nodes
# Community 1874: 1 nodes
# Community 1875: 1 nodes
# Community 1876: 1 nodes
# Community 1877: 1 nodes
# Community 1878: 1 nodes
# Community 1879: 1 nodes
# Community 1880: 1 nodes
# Community 1881: 1 nodes
# Community 1882: 1 nodes
# Community 1883: 1 nodes
# Community 1884: 1 nodes
# Community 1885: 1 nodes
# Community 1886: 1 nodes
# Community 1887: 1 nodes
# Community 1888: 1 nodes
# Community 1889: 1 nodes
# Community 1890: 1 nodes
# Community 1891: 1 nodes
# Community 1892: 1 nodes
# Community 1893: 1 nodes
# Community 1894: 1 nodes
# Community 1895: 1 nodes
# Community 1896: 1 nodes
# Community 1897: 1 nodes
# Community 1898: 1 nodes
# Community 1899: 1 nodes
# Community 1900: 1 nodes
# Community 1901: 1 nodes
# Community 1902: 1 nodes
# Community 1903: 1 nodes
# Community 1904: 1 nodes
# Community 1905: 1 nodes
# Community 1906: 1 nodes
# Community 1907: 1 nodes
# Community 1908: 1 nodes
# Community 1909: 1 nodes
# Community 1910: 1 nodes
# Community 1911: 1 nodes
# Community 1912: 1 nodes
# Community 1913: 1 nodes
# Community 1914: 1 nodes
# Community 1915: 1 nodes
# Community 1916: 1 nodes
# Community 1917: 1 nodes
# Community 1918: 1 nodes
# Community 1919: 1 nodes
# Community 1920: 1 nodes
# Community 1921: 1 nodes
# Community 1922: 1 nodes
# Community 1923: 1 nodes
# Community 1924: 1 nodes
# Community 1925: 1 nodes
# Community 1926: 1 nodes
# Community 1927: 1 nodes
# Community 1928: 1 nodes
# Community 1929: 1 nodes
# Community 1930: 1 nodes
# Community 1931: 1 nodes
# Community 1932: 1 nodes
# Community 1933: 1 nodes
# Community 1934: 1 nodes
# Community 1935: 1 nodes
# Community 1936: 1 nodes
# Community 1937: 1 nodes
# Community 1938: 1 nodes
# Community 1939: 1 nodes
# Community 1940: 1 nodes
# Community 1941: 1 nodes
# Community 1942: 1 nodes
# Community 1943: 1 nodes
# Community 1944: 1 nodes
# Community 1945: 1 nodes
# Community 1946: 1 nodes
# Community 1947: 1 nodes
# Community 1948: 1 nodes
# Community 1949: 1 nodes
# Community 1950: 1 nodes
# Community 1951: 1 nodes
# Community 1952: 1 nodes
# Community 1953: 1 nodes
# Community 1954: 1 nodes
# Community 1955: 1 nodes
# Community 1956: 1 nodes
# Community 1957: 1 nodes
# Community 1958: 1 nodes
# Community 1959: 1 nodes
# Community 1960: 1 nodes
# Community 1961: 1 nodes
# Community 1962: 1 nodes
# Community 1963: 1 nodes
# Community 1964: 1 nodes
# Community 1965: 1 nodes
# Community 1966: 1 nodes
# Community 1967: 1 nodes
# Community 1968: 1 nodes
# Community 1969: 1 nodes
# Community 1970: 1 nodes
# Community 1971: 1 nodes
# Community 1972: 1 nodes
# Community 1973: 1 nodes
# Community 1974: 1 nodes
# Community 1975: 1 nodes
# Community 1976: 1 nodes
# Community 1977: 1 nodes
# Community 1978: 1 nodes
# Community 1979: 1 nodes
# Community 1980: 1 nodes
# Community 1981: 1 nodes
# Community 1982: 1 nodes
# Community 1983: 1 nodes
# Community 1984: 1 nodes
# Community 1985: 1 nodes
# Community 1986: 1 nodes
# Community 1987: 1 nodes
# Community 1988: 1 nodes
# Community 1989: 1 nodes
# Community 1990: 1 nodes
# Community 1991: 1 nodes
# Community 1992: 1 nodes
# Community 1993: 1 nodes
# Community 1994: 1 nodes
# Community 1995: 1 nodes
# Community 1996: 1 nodes
# Community 1997: 1 nodes
# Community 1998: 1 nodes
# Community 1999: 1 nodes
# Community 2000: 1 nodes
# Community 2001: 1 nodes
# Community 2002: 1 nodes
# Community 2003: 1 nodes
# Community 2004: 1 nodes
# Community 2005: 1 nodes
# Community 2006: 1 nodes
# Community 2007: 1 nodes
# Community 2008: 1 nodes
# Community 2009: 1 nodes
# Community 2010: 1 nodes
# Community 2011: 1 nodes
# Community 2012: 1 nodes
# Community 2013: 1 nodes
# Community 2014: 1 nodes
# Community 2015: 1 nodes
# Community 2016: 1 nodes
# Community 2017: 1 nodes
# Community 2018: 1 nodes
# Community 2019: 1 nodes
# Community 2020: 1 nodes
# Community 2021: 1 nodes
# Community 2022: 1 nodes
# Community 2023: 1 nodes
# Community 2024: 1 nodes
# Community 2025: 1 nodes
# Community 2026: 1 nodes
# Community 2027: 1 nodes
# Community 2028: 1 nodes
# Community 2029: 1 nodes
# Community 2030: 1 nodes
# Community 2031: 1 nodes
# Community 2032: 1 nodes
# Community 2033: 1 nodes
# Community 2034: 1 nodes
# Community 2035: 1 nodes
# Community 2036: 1 nodes
# ...
# Community 25216: 1 nodes
# Community 25217: 1 nodes
# Community 25218: 1 nodes
# Community 25219: 1 nodes
# Community 25220: 1 nodes
# Community 25221: 1 nodes
# Community 25222: 1 nodes
# Community 25223: 1 nodes
# Community 25224: 1 nodes
# Community 25225: 1 nodes
# Community 25226: 1 nodes
# Community 25227: 1 nodes
# Community 25228: 1 nodes
# Community 25229: 1 nodes
# Community 25230: 1 nodes
# Community 25231: 1 nodes
# Community 25232: 1 nodes
# Community 25233: 1 nodes
# Community 25234: 1 nodes
# Community 25235: 1 nodes
# Community 25236: 1 nodes
# Community 25237: 1 nodes
# Community 25238: 1 nodes
# Community 25239: 1 nodes
# Community 25240: 1 nodes
# Community 25241: 1 nodes
# Community 25242: 1 nodes
# Community 25243: 1 nodes
# Community 25244: 1 nodes
# Community 25245: 1 nodes
# Community 25246: 1 nodes
# Community 25247: 1 nodes
# Community 25248: 1 nodes
# Community 25249: 1 nodes
# Community 25250: 1 nodes
# Community 25251: 1 nodes
# Community 25252: 1 nodes
# Community 25253: 1 nodes
# Community 25254: 1 nodes
# Community 25255: 1 nodes
# Community 25256: 1 nodes
# Community 25257: 1 nodes
# Community 25258: 1 nodes
# Community 25259: 1 nodes
# Community 25260: 1 nodes
# Community 25261: 1 nodes
# Community 25262: 1 nodes
# Community 25263: 1 nodes
# Community 25264: 1 nodes
# Community 25265: 1 nodes
# Community 25266: 1 nodes
# Community 25267: 1 nodes
# Community 25268: 1 nodes
# Community 25269: 1 nodes
# Community 25270: 1 nodes
# Community 25271: 1 nodes
# Community 25272: 1 nodes
# Community 25273: 1 nodes
# Community 25274: 1 nodes
# Community 25275: 1 nodes
# Community 25276: 1 nodes
# Community 25277: 1 nodes
# Community 25278: 1 nodes
# Community 25279: 1 nodes
# Community 25280: 1 nodes
# Community 25281: 1 nodes
# Community 25282: 1 nodes
# Community 25283: 1 nodes
# Community 25284: 1 nodes
# Community 25285: 1 nodes
# Community 25286: 1 nodes
# Community 25287: 1 nodes
# Community 25288: 1 nodes
# Community 25289: 1 nodes
# Community 25290: 1 nodes
# Community 25291: 1 nodes
# Community 25292: 1 nodes
# Community 25293: 1 nodes
# Community 25294: 1 nodes
# Community 25295: 1 nodes
# Community 25296: 1 nodes
# Community 25297: 1 nodes
# Community 25298: 1 nodes
# Community 25299: 1 nodes
# Community 25300: 1 nodes
# Community 25301: 1 nodes
# Community 25302: 1 nodes
# Community 25303: 1 nodes
# Community 25304: 1 nodes
# Community 25305: 1 nodes
# Community 25306: 1 nodes
# Community 25307: 1 nodes
# Community 25308: 1 nodes
# Community 25309: 1 nodes
# Community 25310: 1 nodes
# Community 25311: 1 nodes
# Community 25312: 1 nodes
# Community 25313: 1 nodes
# Community 25314: 1 nodes
# Community 25315: 1 nodes
# Community 25316: 1 nodes
# Community 25317: 1 nodes
# Community 25318: 1 nodes
# Community 25319: 1 nodes
# Community 25320: 1 nodes
# Community 25321: 1 nodes
# Community 25322: 1 nodes
# Community 25323: 1 nodes
# Community 25324: 1 nodes
# Community 25325: 1 nodes
# Community 25326: 1 nodes
# Community 25327: 1 nodes
# Community 25328: 1 nodes
# Community 25329: 1 nodes
# Community 25330: 1 nodes
# Community 25331: 1 nodes
# Community 25332: 1 nodes
# Community 25333: 1 nodes
# Community 25334: 1 nodes
# Community 25335: 1 nodes
# Community 25336: 1 nodes
# Community 25337: 1 nodes
# Community 25338: 1 nodes
# Community 25339: 1 nodes
# Community 25340: 1 nodes
# Community 25341: 1 nodes
# Community 25342: 1 nodes
# Community 25343: 1 nodes
# Community 25344: 1 nodes
# Community 25345: 1 nodes
# Community 25346: 1 nodes
# Community 25347: 1 nodes
# Community 25348: 1 nodes
# Community 25349: 1 nodes
# Community 25350: 1 nodes
# Community 25351: 1 nodes
# Community 25352: 1 nodes
# Community 25353: 1 nodes
# Community 25354: 1 nodes
# Community 25355: 1 nodes
# Community 25356: 1 nodes
# Community 25357: 1 nodes
# Community 25358: 1 nodes
# Community 25359: 1 nodes
# Community 25360: 1 nodes
# Community 25361: 1 nodes
# Community 25362: 1 nodes
# Community 25363: 1 nodes
# Community 25364: 1 nodes
# Community 25365: 1 nodes
# Community 25366: 1 nodes
# Community 25367: 1 nodes
# Community 25368: 1 nodes
# Community 25369: 1 nodes
# Community 25370: 1 nodes
# Community 25371: 1 nodes
# Community 25372: 1 nodes
# Community 25373: 1 nodes
# Community 25374: 1 nodes
# Community 25375: 1 nodes
# Community 25376: 1 nodes
# Community 25377: 1 nodes
# Community 25378: 1 nodes
# Community 25379: 1 nodes
# Community 25380: 1 nodes
# Community 25381: 1 nodes
# Community 25382: 1 nodes
# Community 25383: 1 nodes
# Community 25384: 1 nodes
# Community 25385: 1 nodes
# Community 25386: 1 nodes
# Community 25387: 1 nodes
# Community 25388: 1 nodes
# Community 25389: 1 nodes
# Community 25390: 1 nodes
# Community 25391: 1 nodes
# Community 25392: 1 nodes
# Community 25393: 1 nodes
# Community 25394: 1 nodes
# Community 25395: 1 nodes
# Community 25396: 1 nodes
# Community 25397: 1 nodes
# Community 25398: 1 nodes
# Community 25399: 1 nodes
# Community 25400: 1 nodes
# Community 25401: 1 nodes
# Community 25402: 1 nodes
# Community 25403: 1 nodes
# Community 25404: 1 nodes
# Community 25405: 1 nodes
# Community 25406: 1 nodes
# Community 25407: 1 nodes
# Community 25408: 1 nodes
# Community 25409: 1 nodes
# Community 25410: 1 nodes
# Community 25411: 1 nodes
# Community 25412: 1 nodes
# Community 25413: 1 nodes
# Community 25414: 1 nodes
# Community 25415: 1 nodes
# Community 25416: 1 nodes
# Community 25417: 1 nodes
# Community 25418: 1 nodes
# Community 25419: 1 nodes
# Community 25420: 1 nodes
# Community 25421: 1 nodes
# Community 25422: 1 nodes
# Community 25423: 1 nodes
# Community 25424: 1 nodes
# Community 25425: 1 nodes
# Community 25426: 1 nodes
# Community 25427: 1 nodes
# Community 25428: 1 nodes
# Community 25429: 1 nodes
# Community 25430: 1 nodes
# Community 25431: 1 nodes
# Community 25432: 1 nodes
# Community 25433: 1 nodes
# Community 25434: 1 nodes
# Community 25435: 1 nodes
# Community 25436: 1 nodes
# Community 25437: 1 nodes
# Community 25438: 1 nodes
# Community 25439: 1 nodes
# Community 25440: 1 nodes
# Community 25441: 1 nodes
# Community 25442: 1 nodes
# Community 25443: 1 nodes
# Community 25444: 1 nodes
# Community 25445: 1 nodes
# Community 25446: 1 nodes
# Community 25447: 1 nodes
# Community 25448: 1 nodes
# Community 25449: 1 nodes
# Community 25450: 1 nodes
# Community 25451: 1 nodes
# Community 25452: 1 nodes
# Community 25453: 1 nodes
# Community 25454: 1 nodes
# Community 25455: 1 nodes
# Community 25456: 1 nodes
# Community 25457: 1 nodes
# Community 25458: 1 nodes
# Community 25459: 1 nodes
# Community 25460: 1 nodes
# Community 25461: 1 nodes
# Community 25462: 1 nodes
# Community 25463: 1 nodes
# Community 25464: 1 nodes
# Community 25465: 1 nodes
# Community 25466: 1 nodes
# Community 25467: 1 nodes
# Community 25468: 1 nodes
# Community 25469: 1 nodes
# Community 25470: 1 nodes
# Community 25471: 1 nodes
# Community 25472: 1 nodes
# Community 25473: 1 nodes
# Community 25474: 1 nodes
# Community 25475: 1 nodes
# Community 25476: 1 nodes
# Community 25477: 1 nodes
# Community 25478: 1 nodes
# Community 25479: 1 nodes
# Community 25480: 1 nodes
# Community 25481: 1 nodes
# Community 25482: 1 nodes
# Community 25483: 1 nodes
# Community 25484: 1 nodes
# Community 25485: 1 nodes
# Community 25486: 1 nodes
# Community 25487: 1 nodes
# Community 25488: 1 nodes
# Community 25489: 1 nodes
# Community 25490: 1 nodes
# Community 25491: 1 nodes
# Community 25492: 1 nodes
# Community 25493: 1 nodes
# Community 25494: 1 nodes
# Community 25495: 1 nodes
# Community 25496: 1 nodes
# Community 25497: 1 nodes
# Community 25498: 1 nodes
# Community 25499: 1 nodes
# Community 25500: 1 nodes
# Community 25501: 1 nodes
# Community 25502: 1 nodes
# Community 25503: 1 nodes
# Community 25504: 1 nodes
# Community 25505: 1 nodes
# Community 25506: 1 nodes
# Community 25507: 1 nodes
# Community 25508: 1 nodes
# Community 25509: 1 nodes
# Community 25510: 1 nodes
# Community 25511: 1 nodes
# Community 25512: 1 nodes
# Community 25513: 1 nodes
# Community 25514: 1 nodes
# Community 25515: 1 nodes
# Community 25516: 1 nodes
# Community 25517: 1 nodes
# Community 25518: 1 nodes
# Community 25519: 1 nodes
# Community 25520: 1 nodes
# Community 25521: 1 nodes
# Community 25522: 1 nodes
# Community 25523: 1 nodes
# Community 25524: 1 nodes
# Community 25525: 1 nodes
# Community 25526: 1 nodes
# Community 25527: 1 nodes
# Community 25528: 1 nodes
# Community 25529: 1 nodes
# Community 25530: 1 nodes
# Community 25531: 1 nodes
# Community 25532: 1 nodes
# Community 25533: 1 nodes
# Community 25534: 1 nodes
# Community 25535: 1 nodes
# Community 25536: 1 nodes
# Community 25537: 1 nodes
# Community 25538: 1 nodes
# Community 25539: 1 nodes
# Community 25540: 1 nodes
# Community 25541: 1 nodes
# Community 25542: 1 nodes
# Community 25543: 1 nodes
# Community 25544: 1 nodes
# Community 25545: 1 nodes
# Community 25546: 1 nodes
# Community 25547: 1 nodes
# Community 25548: 1 nodes
# Community 25549: 1 nodes
# Community 25550: 1 nodes
# Community 25551: 1 nodes
# Community 25552: 1 nodes
# Community 25553: 1 nodes
# Community 25554: 1 nodes
# Community 25555: 1 nodes
# Community 25556: 1 nodes
# Community 25557: 1 nodes
# Community 25558: 1 nodes
# Community 25559: 1 nodes
# Community 25560: 1 nodes
# Community 25561: 1 nodes
# Community 25562: 1 nodes
# Community 25563: 1 nodes
# Community 25564: 1 nodes
# Community 25565: 1 nodes
# Community 25566: 1 nodes
# Community 25567: 1 nodes
# Community 25568: 1 nodes
# Community 25569: 1 nodes
# Community 25570: 1 nodes
# Community 25571: 1 nodes
# Community 25572: 1 nodes
# Community 25573: 1 nodes
# Community 25574: 1 nodes
# Community 25575: 1 nodes
# Community 25576: 1 nodes
# Community 25577: 1 nodes
# Community 25578: 1 nodes
# Community 25579: 1 nodes
# Community 25580: 1 nodes
# Community 25581: 1 nodes
# Community 25582: 1 nodes
# Community 25583: 1 nodes
# Community 25584: 1 nodes
# Community 25585: 1 nodes
# Community 25586: 1 nodes
# Community 25587: 1 nodes
# Community 25588: 1 nodes
# Community 25589: 1 nodes
# Community 25590: 1 nodes
# Community 25591: 1 nodes
# Community 25592: 1 nodes
# Community 25593: 1 nodes
# Community 25594: 1 nodes
# Community 25595: 1 nodes
# Community 25596: 1 nodes
# Community 25597: 1 nodes
# Community 25598: 1 nodes
# Community 25599: 1 nodes
# Community 25600: 1 nodes
# Community 25601: 1 nodes
# Community 25602: 1 nodes
# Community 25603: 1 nodes
# Community 25604: 1 nodes
# Community 25605: 1 nodes
# Community 25606: 1 nodes
# Community 25607: 1 nodes
# Community 25608: 1 nodes
# Community 25609: 1 nodes
# Community 25610: 1 nodes
# Community 25611: 1 nodes
# Community 25612: 1 nodes
# Community 25613: 1 nodes
# Community 25614: 1 nodes
# Community 25615: 1 nodes
# Community 25616: 1 nodes
# Community 25617: 1 nodes
# Community 25618: 1 nodes
# Community 25619: 1 nodes
# Community 25620: 1 nodes
# Community 25621: 1 nodes
# Community 25622: 1 nodes
# Community 25623: 1 nodes
# Community 25624: 1 nodes
# Community 25625: 1 nodes
# Community 25626: 1 nodes
# Community 25627: 1 nodes
# Community 25628: 1 nodes
# Community 25629: 1 nodes
# Community 25630: 1 nodes
# Community 25631: 1 nodes
# Community 25632: 1 nodes
# Community 25633: 1 nodes
# Community 25634: 1 nodes
# Community 25635: 1 nodes
# Community 25636: 1 nodes
# Community 25637: 1 nodes
# Community 25638: 1 nodes
# Community 25639: 1 nodes
# Community 25640: 1 nodes
# Community 25641: 1 nodes
# Community 25642: 1 nodes
# Community 25643: 1 nodes
# Community 25644: 1 nodes
# Community 25645: 1 nodes
# Community 25646: 1 nodes
# Community 25647: 1 nodes
# Community 25648: 1 nodes
# Community 25649: 1 nodes
# Community 25650: 1 nodes
# Community 25651: 1 nodes
# Community 25652: 1 nodes
# Community 25653: 1 nodes
# Community 25654: 1 nodes
# Community 25655: 1 nodes
# Community 25656: 1 nodes
# Community 25657: 1 nodes
# Community 25658: 1 nodes
# Community 25659: 1 nodes
# Community 25660: 1 nodes
# Community 25661: 1 nodes
# Community 25662: 1 nodes
# Community 25663: 1 nodes
# Community 25664: 1 nodes
# Community 25665: 1 nodes
# Community 25666: 1 nodes
# Community 25667: 1 nodes
# Community 25668: 1 nodes
# Community 25669: 1 nodes
# Community 25670: 1 nodes
# Community 25671: 1 nodes
# Community 25672: 1 nodes
# Community 25673: 1 nodes
# Community 25674: 1 nodes
# Community 25675: 1 nodes
# Community 25676: 1 nodes
# Community 25677: 1 nodes
# Community 25678: 1 nodes
# Community 25679: 1 nodes
# Community 25680: 1 nodes
# Community 25681: 1 nodes
# Community 25682: 1 nodes
# Community 25683: 1 nodes
# Community 25684: 1 nodes
# Community 25685: 1 nodes
# Community 25686: 1 nodes
# Community 25687: 1 nodes
# Community 25688: 1 nodes
# Community 25689: 1 nodes
# Community 25690: 1 nodes
# Community 25691: 1 nodes
# Community 25692: 1 nodes
# Community 25693: 1 nodes
# Community 25694: 1 nodes
# Community 25695: 1 nodes
# Community 25696: 1 nodes
# Community 25697: 1 nodes
# Community 25698: 1 nodes
# Community 25699: 1 nodes
# Community 25700: 1 nodes
# Community 25701: 1 nodes
# Community 25702: 1 nodes
# Community 25703: 1 nodes
# Community 25704: 1 nodes
# Community 25705: 1 nodes
# Community 25706: 1 nodes
# Community 25707: 1 nodes
# Community 25708: 1 nodes
# Community 25709: 1 nodes
# Community 25710: 1 nodes
# Community 25711: 1 nodes
# Community 25712: 1 nodes
# Community 25713: 1 nodes
# Community 25714: 1 nodes
# Community 25715: 1 nodes
# Community 25716: 1 nodes
# Community 25717: 1 nodes
# Community 25718: 1 nodes
# Community 25719: 1 nodes
# Community 25720: 1 nodes
# Community 25721: 1 nodes
# Community 25722: 1 nodes
# Community 25723: 1 nodes
# Community 25724: 1 nodes
# Community 25725: 1 nodes
# Community 25726: 1 nodes
# Community 25727: 1 nodes
# Community 25728: 1 nodes
# Community 25729: 1 nodes
# Community 25730: 1 nodes
# Community 25731: 1 nodes
# Community 25732: 1 nodes
# Community 25733: 1 nodes
# Community 25734: 1 nodes
# Community 25735: 1 nodes
# Community 25736: 1 nodes
# Community 25737: 1 nodes
# Community 25738: 1 nodes
# Community 25739: 1 nodes
# Community 25740: 1 nodes
# Community 25741: 1 nodes
# Community 25742: 1 nodes
# Community 25743: 1 nodes
# Community 25744: 1 nodes
# Community 25745: 1 nodes
# Community 25746: 1 nodes
# Community 25747: 1 nodes
# Community 25748: 1 nodes
# Community 25749: 1 nodes
# Community 25750: 1 nodes
# Community 25751: 1 nodes
# Community 25752: 1 nodes
# Community 25753: 1 nodes
# Community 25754: 1 nodes
# Community 25755: 1 nodes
# Community 25756: 1 nodes
# Community 25757: 1 nodes
# Community 25758: 1 nodes
# Community 25759: 1 nodes
# Community 25760: 1 nodes
# Community 25761: 1 nodes
# Community 25762: 1 nodes
# Community 25763: 1 nodes
# Community 25764: 1 nodes
# Community 25765: 1 nodes
# Community 25766: 1 nodes
# Community 25767: 1 nodes
# Community 25768: 1 nodes
# Community 25769: 1 nodes
# Community 25770: 1 nodes
# Community 25771: 1 nodes
# Community 25772: 1 nodes
# Community 25773: 1 nodes
# Community 25774: 1 nodes
# Community 25775: 1 nodes
# Community 25776: 1 nodes
# Community 25777: 1 nodes
# Community 25778: 1 nodes
# Community 25779: 1 nodes
# Community 25780: 1 nodes
# Community 25781: 1 nodes
# Community 25782: 1 nodes
# Community 25783: 1 nodes
# Community 25784: 1 nodes
# Community 25785: 1 nodes
# Community 25786: 1 nodes
# Community 25787: 1 nodes
# Community 25788: 1 nodes
# Community 25789: 1 nodes
# Community 25790: 1 nodes
# Community 25791: 1 nodes
# Community 25792: 1 nodes
# Community 25793: 1 nodes
# Community 25794: 1 nodes
# Community 25795: 1 nodes
# Community 25796: 1 nodes
# Community 25797: 1 nodes
# Community 25798: 1 nodes
# Community 25799: 1 nodes
# Community 25800: 1 nodes
# Community 25801: 1 nodes
# Community 25802: 1 nodes
# Community 25803: 1 nodes
# Community 25804: 1 nodes
# Community 25805: 1 nodes
# Community 25806: 1 nodes
# Community 25807: 1 nodes
# Community 25808: 1 nodes
# Community 25809: 1 nodes
# Community 25810: 1 nodes
# Community 25811: 1 nodes
# Community 25812: 1 nodes
# Community 25813: 1 nodes
# Community 25814: 1 nodes
# Community 25815: 1 nodes
# Community 25816: 1 nodes
# Community 25817: 1 nodes
# Community 25818: 1 nodes
# Community 25819: 1 nodes
# Community 25820: 1 nodes
# Community 25821: 1 nodes
# Community 25822: 1 nodes
# Community 25823: 1 nodes
# Community 25824: 1 nodes
# Community 25825: 1 nodes
# Community 25826: 1 nodes
# Community 25827: 1 nodes
# Community 25828: 1 nodes
# Community 25829: 1 nodes
# Community 25830: 1 nodes
# Community 25831: 1 nodes
# Community 25832: 1 nodes
# Community 25833: 1 nodes
# Community 25834: 1 nodes
# Community 25835: 1 nodes
# Community 25836: 1 nodes
# Community 25837: 1 nodes
# Community 25838: 1 nodes
# Community 25839: 1 nodes
# Community 25840: 1 nodes
# Community 25841: 1 nodes
# Community 25842: 1 nodes
# Community 25843: 1 nodes
# Community 25844: 1 nodes
# Community 25845: 1 nodes
# Community 25846: 1 nodes
# Community 25847: 1 nodes
# Community 25848: 1 nodes
# Community 25849: 1 nodes
# Community 25850: 1 nodes
# Community 25851: 1 nodes
# Community 25852: 1 nodes
# Community 25853: 1 nodes
# Community 25854: 1 nodes
# Community 25855: 1 nodes

# %% [markdown]
# Now that we have a graph in memory, we can generate communities using
# :meth:`igraph.Graph.community_edge_betweenness` to separate out vertices into
# clusters. (For a more focused tutorial on just visualising communities, check
# out `tutorials-visualize-communities`).

# %%
communities = g.community_edge_betweenness()
communities = communities.as_clustering()

# %% [markdown]
# We can also easily print out who belongs to each community:

# %%
num_communities = len(communities)
palette = ig.RainbowPalette(n=num_communities)
for i, community in enumerate(communities):
    g.vs[community]["color"] = i
    community_edges = g.es.select(_within=community)
    community_edges["color"] = i

# %%
fig, ax = plt.subplots()
ig.plot(
    communities,
    palette=palette,
    edge_width=1,
    target=ax,
    vertex_size=20,
)

# Create a custom color legend
legend_handles = []
for i in range(num_communities):
    handle = ax.scatter(
        [], [],
        s=100,
        facecolor=palette.get(i),
        edgecolor="k",
        label=i,
    )
    legend_handles.append(handle)
ax.legend(
    handles=legend_handles,
    title='Community:',
    bbox_to_anchor=(0, 1.0),
    bbox_transform=ax.transAxes,
)
plt.show()

# %% [markdown]
# Finally we can proceed to plotting the graph. In order to make each community
# stand out, we set "community colors" using an igraph palette:

# %%
num_communities = len(communities)
palette1 = ig.RainbowPalette(n=num_communities)
for i, community in enumerate(communities):
    g.vs[community]["color"] = i
    community_edges = g.es.select(_within=community)
    community_edges["color"] = i

# %% [markdown]
# We can use a dirty hack to move the labels below the vertices ;-)

# %%
g.vs["label"] = ["\n\n" + label for label in g.vs["label"]]

# %% [markdown]
# Finally, we can plot the communities:

# %%
fig1, ax1 = plt.subplots()
ig.plot(
    communities,
    target=ax1,
    mark_groups=True,
    palette=palette1,
    vertex_size=15,
    edge_width=0.5,
)
fig1.set_size_inches(20, 20)

# %% [markdown]
# Now let's try and contract the information down, using only a single vertex
# to represent each community. We start by defining x, y, and size attributes
# for each node in the original graph:

# %%
layout = g.layout_kamada_kawai()
g.vs["x"], g.vs["y"] = list(zip(*layout))
g.vs["size"] = 15
g.es["size"] = 15

# %% [markdown]
# Then we can generate the cluster graph that compresses each community into a
# single, "composite" vertex using
# :meth:`igraph.VertexClustering.cluster_graph`:

# %%
cluster_graph = communities.cluster_graph(
    combine_vertices={
        "x": "mean",
        "y": "mean",
        "color": "first",
        "size": "sum",
    },
    combine_edges={
        "size": "sum",
    },
)

# %% [markdown]
# <div class="alert alert-info"><h4>Note</h4><p>We took the mean of x and y values so that the nodes in the cluster
#      graph are placed at the centroid of the original cluster.</p></div>
#
# <div class="alert alert-info"><h4>Note</h4><p>``mean``, ``first``, and ``sum`` are all built-in collapsing functions,
#     along with ``prod``, ``median``, ``max``, ``min``, ``last``, ``random``.
#     You can also define your own custom collapsing functions, which take in a
#     list and return a single element representing the combined attribute
#     value. For more details on igraph contraction, see
#     :meth:`igraph.GraphBase.contract_vertices`.</p></div>

# %% [markdown]
# Finally, we can assign colors to the clusters and plot the cluster graph,
# including a legend to make things clear:

# %%
palette2 = ig.GradientPalette("gainsboro", "black")
g.es["color"] = [palette2.get(int(i)) for i in ig.rescale(cluster_graph.es["size"], (0, 255), clamp=True)]

fig2, ax2 = plt.subplots()
ig.plot(
    cluster_graph,
    target=ax2,
    palette=palette1,
    # set a minimum size on vertex_size, otherwise vertices are too small
    vertex_size=[max(20, size) for size in cluster_graph.vs["size"]],
    edge_color=g.es["color"],
    edge_width=0.8,
)

# Add a legend
legend_handles = []
for i in range(num_communities):
    handle = ax2.scatter(
        [], [],
        s=100,
        facecolor=palette1.get(i),
        edgecolor="k",
        label=i,
    )
    legend_handles.append(handle)

ax2.legend(
    handles=legend_handles,
    title='Community:',
    bbox_to_anchor=(0, 1.0),
    bbox_transform=ax2.transAxes,
)

fig2.set_size_inches(10, 10)
